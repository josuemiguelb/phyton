# %% [markdown]
# ## Excercise 1
# When you create the files, we need to keep in mind these points.
# 1.Do not type the line number on the left.
# 2.I have the print at the beginning of the line,every single character has to match for it to work. Color doesn't matter, only the characters you type.

# %%
print("Hello World")
print("This is great")
print("this is fun ")
print("Owrs names are Josue and Oswaldo")
# Out:
# Hello World
# This is great
# this is fun
# Owrs names are Josue and Oswaldo

# %% [markdown]
# ## Exercise 2
# Commons are very important in your programs, they are used to tell us what something does in English, and they are used to disable parts of your program.
# Like #

# %%
#this is a program show a text in the screen
print("This message will appear")
#print("This message wont appear in the program")
#another example, to identify what we are doing
b=2
h=1
a=b*h  #this operation is to obtain the area of a rectangle
print(a)#result will appear
# Out:
# This message will appear
# 2

# %% [markdown]
# ## Exercise 3
# Every programming language has some kind of way of doing numbers and math. This excersice have a lot of math symbols
# .+ plus
# .- minus
# ./ slash
# .* asterisk
# .% percent
# .< less-than
# .> greater-than
# .<= less-than-equal
# .>= greater than equal

# %%
print("get the average of these ratings: 10,4,7,9")
print((10+4+7+9)/4)


print("4/3>4/2 ?")
print(4/3>4/2)
# Out:
# get the average of these ratings: 10,4,7,9
# 7.5
# 4/3>4/2 ?
# False

# %% [markdown]
# ## Exercise 4
# In this we need to learn about variables, in programmin, a variable is nothing more than a namefor something.

# %%
cats=10
flowers=25
pots=20
soldcats=cats-3
catsnow=cats-soldcats
flowers_without_pot=pots-flowers
pots_without_flowers=flowers-pots



print("In my house there were", cats ,"cats but i sold",soldcats," cats, now i've got ",catsnow, " cats")
print("In the garden there are ",flowers, "flowers but there is a problem, we only have ",pots,"pots")
print(pots_without_flowers," will be missing")
# Out:
# In my house there were 10 cats but i sold 7  cats, now i've got  3  cats
# In the garden there are  25 flowers but there is a problem, we only have  20 pots
# 5  will be missing

# %% [markdown]
# ## Exercise 5
# In this exercise, we are going to print more variables. Now we are going to use a "format string".
# Every time you put around a piece of text you have been making a string.
# A string is how you make something that your program might give to a human. Strings are really handly.
# So we will learn about how to make strings that have variables embedded in them.

# %%
my_pet = 'Solobino'
my_pet_age = 5 #i guess 
my_pet_weight = 14 #kg
breed='pastor aleman'
moreweight=2 
new=my_pet_weight+moreweight
print(f"In my house I´ve got a pet its name is {my_pet}.")
print(f"{my_pet} ´s weight is {my_pet_weight} kilograms heavy")
print(f"{my_pet} plays a lot")
print(f"Its breed is {breed}")

# this line is tricky, try to get it exactly right

print(f"The last days he was eating a lot. {my_pet} is increasing its weight,more clear {moreweight} kilograms, so his new weight is {new} kilograms")
# Out:
# In my house I´ve got a pet its name is Solobino.
# Solobino ´s weight is 14 kilograms heavy
# Solobino plays a lot
# Its breed is pastor aleman
# The last days he was eating a lot. Solobino is increasing its weight,more clear 2 kilograms, so his new weight is 16 kilograms

# %% [markdown]
# ## Exercise 6
# In this exercise we create a bunch of variables with complex strings so you can see what are they for. A string is usuallya bit of text you want to display to someone or export out of the program you are writing. Strings can contain any number of variables that are in Python script. We will now type in a whole bunch of strings, variables and formats and print them.

# %%
planets=9
planetsleft=8
w=f" In the solar system there used to be {planets} but the scientists have discontinued pluto as a planet now there are {planetsleft} oficially"
print(w)
sun=False
question="Is the Sun made by lava? {}"
print(question.format(sun))
a=f"the sun is mainly made up of hydrogen  "
b=f"and helium"
print(a+b)
# Out:
#  In the solar system there used to be 9 but the scientists have discontinued pluto as a planet now there are 8 oficially
# Is the Sun made by lava? False
# the sun is mainly made up of hydrogen  and helium

# %% [markdown]
# ## Exercise 7
# Now we are going to do a bunch of exercises where you just type code in and make it run. Use everything that you learned in the previous exercises.

# %%
print("My name is Paco")
print("My favorite subjets is {}".format('History'))
print("."*20)
e1="t"
e2="h"
e3="i"
e4="s"
e5="i"
e6="s"
e7="a"
e8="w"
e9="e"
e10="s"
e11="o"
e12="m"
e13="e"
s=" "
print(e1+e2+e3+e4+s+e5+e6+s+e7+e8+e9+e10+e11+e12+e13)#in this case we use "s" for spaces
# Out:
# My name is Paco
# My favorite subjets is History
# ....................
# this is awesome

# %% [markdown]
# ## Exercise 8
# In this exercise, we are going to use something called a function to turn the formatter variable into other strings.

# %%
formatter = "{} {} {} {}"

print(formatter.format("I", "II", "III", "IV"))
print(formatter.format("one", "two", "three", "four"))
print(formatter.format(True, False, False, True))
print(formatter.format(formatter, formatter, formatter, formatter))
print(formatter.format(
"I hope you learn",
   "you need to study",
    "to pass ",
    "the subjet",
))
# Out:
# I II III IV
# one two three four
# True False False True
# {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
# I hope you learn you need to study to pass  the subjet

# %% [markdown]
# ## Exercise 9
# In this exercise, we printed a code with variabless that can possibly be the months or days with a string that goes across multiple lines. We practice everything that we learned in the previous exercises.

# %%
#example
subjets="Sciences  mathematics philosophy  visual arts " #there are the subjets of one student
foods="Pizza\nTacos\nHamburguers\nFried Chicken\nCake\nBurritos"
f=f"These are the subjets: {subjets}"
print(f)
print("this is the menu",foods)
#THIS IS A POEM
print("""
You are in need of everything:
grey roads,
deep glooms,
birds that sing even in silence;
the sky,
an autumn leaf,
hands empty,
love unreturning,
snow’s whiteness;
dawn lights,
you are in need of everything the dream requires,
to become one with the music
of the most faraway blues
so that eventually your soul
will have confidence in death.
""")
# Out:
# These are the subjets: Sciences  mathematics philosophy  visual arts
# this is the menu Pizza
# Tacos
# Hamburguers
# Fried Chicken
# Cake
# Burritos
#
# You are in need of everything:
# grey roads,
# deep glooms,
# birds that sing even in silence;
# the sky,
# an autumn leaf,
# hands empty,
# love unreturning,
# snow’s whiteness;
# dawn lights,
# you are in need of everything the dream requires,
# to become one with the music
# of the most faraway blues
# so that eventually your soul
# will have confidence in death.

# %% [markdown]
# ## Exercise 10
# There are various escape sequences available for different characters you migh want to use. Well try a few of these sequences that you can see what is the meaning of this. In this we are going to use the "escape double-quote", so Python knows how to include them in a string. Also you have a table about Escape Sequences.
# \\ Backlash
# \' Single quote
# \" Double quote
# \a ASCII bell
# \b ASCII backspace
# \f ASCII formfeed

# %%
introduction="\tThis is the Title"
question_answer="How are you? \n-I'm fine and you?"

listd="""
Materials
\t* Eraser
\t* Pencils\n\t* Notebooks
"""
print(introduction)
print(question_answer)
print(listd)
# Out:
# 	This is the Title
# How are you?
# -I'm fine and you?
#
# Materials
# 	* Eraser
# 	* Pencils
# 	* Notebooks
